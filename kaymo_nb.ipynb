# %%
from pprint import pprint as p
import sys

p(sys.path)
# Out:
# ['/Users/amrmkayid/anaconda3/envs/kaymo/lib/python36.zip',
#  '/Users/amrmkayid/anaconda3/envs/kaymo/lib/python3.6',
#  '/Users/amrmkayid/anaconda3/envs/kaymo/lib/python3.6/lib-dynload',
#  '',
#  '/Users/amrmkayid/anaconda3/envs/kaymo/lib/python3.6/site-packages',
#  '/Users/amrmkayid/anaconda3/envs/kaymo/lib/python3.6/site-packages/IPython/extensions',
#  '/Users/amrmkayid/.ipython']

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path, PosixPath

from kaymo import AudioItem

# %% [markdown]
# ## AudioItem

# %%
path_example = Path('datasets/kaymodb/happy/0_emodb_happy_1.wav')
path_example
# Out:
# PosixPath('datasets/kaymodb/happy/0_emodb_happy_1.wav')

# %%
sound = AudioItem.open(path_example)
sound
# Out:
# AudioItem AudioItem 2.1 seconds (33542 samples @ 16000hz)

# %%
sound.shape, sound.data_signal, sound.sample_rate, sound.path
# Out:
# (torch.Size([33542]),
#  tensor([ 0.0029,  0.0029, -0.0015,  ...,  0.0000, -0.0002,  0.0000]),
#  16000,
#  PosixPath('datasets/kaymodb/happy/0_emodb_happy_1.wav'))

# %%
len(sound)
# Out:
# 33542

# %%
sound.show()
# Out:
# File: datasets/kaymodb/happy/0_emodb_happy_1.wav
# Total Length: 2.1 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sound.duration
# Out:
# 2.096375

# %%
sound.data
# Out:
# tensor([ 0.0029,  0.0029, -0.0015,  ...,  0.0000, -0.0002,  0.0000])
